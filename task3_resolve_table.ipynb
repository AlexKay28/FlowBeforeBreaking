# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
from task3 import main as launch

task3_table = pd.read_csv('task3_table_data.csv').reset_index()
task3_table['Cld'] = task3_table.apply(lambda row: launch(**row[['Dout', 't', 'T', 'p', 'steel_type', 'Nz', 'Mx', 'My', 'dva_c_max','defect_type', 'index']].to_dict()), axis=1)
task3_table
# Out:
# 0
# 1
# 2
# 6
# 7
# 8
# 12
# 13
# 14
#    level_0  index       defect_type  steel_type Название СС   Dout      t  \
# 0        0      0  Кольцевой дефект    Сталь 20         208  0.273  0.016
# 1        1      1  Кольцевой дефект    Сталь 20         210  0.273  0.016
# 2        2      2  Кольцевой дефект    Сталь 20         227  0.273  0.016
# 3        3      6  Кольцевой дефект    Сталь 20          32  0.325  0.019
# 4        4      7  Кольцевой дефект    Сталь 20           6  0.325  0.019
# 5        5      8  Кольцевой дефект    Сталь 20         445  0.325  0.019
# 6        6     12  Кольцевой дефект  Cталь 16ГС        311a  0.426  0.024
# 7        7     13  Кольцевой дефект    Сталь 20        311b  0.426  0.024
# 8        8     14  Кольцевой дефект    Сталь 20        349a  0.426  0.024
#
#      T          p       Nz       Mx       My  dva_c_max      sig_b      sig_m  \
# 0  285  6900000.0  10000.0   6940.0 -13507.0   0.428827  19.435045  25.139305
# ...
